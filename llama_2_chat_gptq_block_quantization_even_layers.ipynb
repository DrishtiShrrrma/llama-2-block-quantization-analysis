# %%
# !pip install -q -U transformers peft accelerate optimum
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 53.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.6/85.6 kB 13.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.2/251.2 kB 30.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 396.1/396.1 kB 43.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 33.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 115.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 84.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 6.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.6/519.6 kB 52.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 87.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 12.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 15.5 MB/s eta 0:00:00
# ...

# %%
# !pip install auto-gptq --extra-index-url https://huggingface.github.io/autogptq-index/whl/cu117/
# Out:
# Looking in indexes: https://pypi.org/simple, https://huggingface.github.io/autogptq-index/whl/cu117/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 26.8 MB/s eta 0:00:00
# ...

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, GPTQConfig
import torch

# %%
from peft import prepare_model_for_kbit_training

model_id = "TheBloke/Llama-2-7b-Chat-GPTQ"
quantization_config_loading = GPTQConfig(bits=4, disable_exllama=True, block_name_to_quantize=[f"model.layers.{i}" for i in range(32) if i % 2 == 0])
model = AutoModelForCausalLM.from_pretrained(model_id,quantization_config=quantization_config_loading, device_map="auto")
# Out:
# ...
# You passed `quantization_config` to `from_pretrained` but the model you're loading already has a `quantization_config` attribute and has already quantized weights. However, loading attributes (e.g. disable_exllama, use_cuda_fp16) will be overwritten with the one you passed to `from_pretrained`. The rest will be ignored.
# ...

# %%
model.config.quantization_config.to_dict()
# Out:
# {'quant_method': <QuantizationMethod.GPTQ: 'gptq'>,
#  'bits': 4,
#  'tokenizer': None,
#  'dataset': None,
#  'group_size': 128,
#  'damp_percent': 0.01,
#  'desc_act': False,
#  'sym': True,
#  'true_sequential': True,
#  'use_cuda_fp16': False,
#  'model_seqlen': None,
#  'block_name_to_quantize': None,
#  'module_name_preceding_first_block': None,
#  'batch_size': 1,
#  'pad_token_id': None,
#  'disable_exllama': True}

# %%
model = prepare_model_for_kbit_training(model)

# %%
from peft import LoraConfig, get_peft_model
config = LoraConfig(
    r=8,
    lora_alpha=32,
    target_modules=["k_proj","o_proj","q_proj","v_proj"],
    lora_dropout=0.05,
    bias="none",
    task_type="CAUSAL_LM"
)

model = get_peft_model(model, config)
model.print_trainable_parameters()
# Out:
# trainable params: 8,388,608 || all params: 270,798,848 || trainable%: 3.097726619575575

# %%
tokenizer = AutoTokenizer.from_pretrained(model_id)

# %%
from datasets import load_dataset

data = load_dataset("Abirate/english_quotes")
data = data.map(lambda samples: tokenizer(samples["quote"]), batched=True)
# Out:
# ...
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Map:   0%|          | 0/2508 [00:00<?, ? examples/s]

# %%
data
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['quote', 'author', 'tags', 'input_ids', 'attention_mask'],
#         num_rows: 2508
#     })
# })

# %%
data = data["train"].train_test_split(seed=42, shuffle=True, test_size=0.2)
data
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['quote', 'author', 'tags', 'input_ids', 'attention_mask'],
#         num_rows: 2006
#     })
#     test: Dataset({
#         features: ['quote', 'author', 'tags', 'input_ids', 'attention_mask'],
#         num_rows: 502
#     })
# })

# %%
from transformers import Trainer, TrainingArguments, DataCollatorForLanguageModeling

# needed for llama 2 tokenizer
tokenizer.pad_token = tokenizer.eos_token

trainer = Trainer(
    model=model,
    train_dataset=data["train"],
    eval_dataset=data["test"],
    args=TrainingArguments(
        per_device_train_batch_size=1,
        per_device_eval_batch_size=1,
        evaluation_strategy="steps",
        eval_steps=50,
        max_steps=200,
        learning_rate=2e-4,
        logging_steps=50,
        output_dir="outputs",
        optim="adamw_hf"
    ),
    data_collator=DataCollatorForLanguageModeling(tokenizer, mlm=False)
)

# %%
model.config.use_cache = False  # silence the warnings. Please re-enable for inference!
trainer.train()
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:411: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# You're using a LlamaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='200' max='200' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [200/200 06:14, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>2.654300</td>
# ...

# %%
from huggingface_hub import HfApi
api = HfApi()

# %%
from huggingface_hub import notebook_login
notebook_login()

# %%
api.create_repo("DrishtiSharma/llama-2-chat-gptq-block-quantization-even-layers")
# Out:
# RepoUrl('https://huggingface.co/DrishtiSharma/llama-2-chat-gptq-block-quantization-even-layers', endpoint='https://huggingface.co', repo_type='model', repo_id='DrishtiSharma/llama-2-chat-gptq-block-quantization-even-layers')

# %%
api.upload_folder(
    folder_path = "/content/outputs",
    path_in_repo = ".",
    repo_id = "DrishtiSharma/llama-2-chat-gptq-block-quantization-even-layers",
    repo_type = "model"
                  )
# Out:
# events.out.tfevents.1694375487.f43f960a1ece.4921.0:   0%|          | 0.00/6.60k [00:00<?, ?B/s]
# 'https://huggingface.co/DrishtiSharma/llama-2-chat-gptq-block-quantization-even-layers/tree/main/.'
